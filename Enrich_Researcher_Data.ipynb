# %% [markdown]
# ### Enriching researcher data
#
# This notebook is used to enrich the csv file containing the researcher data, in order to suit our needs for lab 3.

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/alfredo.leon/Desktop/SDMLab1/PropertyGraphsLab/neo4jcontainerdata/dataset.csv", encoding='latin1')
df.head(n=3).T
# Out:
#                                                                            0  \
# Authors                    Khah F.S., Rybkowski Z.K., Ray Pentecost A., S...
# Author(s) ID               57215333932;34868658300;57215305002;7410171017...
# Title                      Development and testing of an innovative archi...
# Year                                                                    2019
# Source title               27th Annual Conference of the International Gr...
# General conference name    Annual Conference of the International Group f...
# Volume                                                                 IGLC1
# Issue                                                                    NaN
# Art. No.                                                                 NaN
# Page start                                                             515.0
# Page end                                                               526.0
# Page count                                                               NaN
# Cited by                                                                 NaN
# DOI                                                       10.24928/2019/0221
# Link                       https://www.scopus.com/inward/record.uri?eid=2...
# Affiliations               Department of Construction Science, Texas A an...
# Authors with affiliations  Khah, F.S., Department of Construction Science...
# Abstract                   More than half of international construction p...
# Author Keywords            Architectural programming; Design science; Ser...
# Index Keywords             Decision making; Lean production; Serious game...
# Document Type                                                     Conference
# Publication Stage                                                      Final
# Access Type                                                      Open Access
# Source                                                                Scopus
# EID                                                       2-s2.0-85078303158
#
#                                                                            1  \
# Authors                                               Nielsen J., Beard R.W.
# Author(s) ID                                        56824897200;35562442700;
# Title                      Relative target estimation using a cascade of ...
# Year                                                                    2017
# Source title               30th International Technical Meeting of the Sa...
# General conference name    International Technical Meeting of the Satelli...
# Volume                                                                     4
# Issue                                                                    NaN
# Art. No.                                                                 NaN
# Page start                                                            2273.0
# Page end                                                              2289.0
# Page count                                                               NaN
# Cited by                                                                 2.0
# DOI                                                      10.33012/2017.15158
# Link                       https://www.scopus.com/inward/record.uri?eid=2...
# Affiliations                         Brigham Young University, United States
# Authors with affiliations  Nielsen, J., Brigham Young University, United ...
# Abstract                   This paper presents a method of tracking multi...
# Author Keywords                                                          NaN
# Index Keywords             Aircraft detection; Antennas; Cameras; Global ...
# Document Type                                                     Conference
# Publication Stage                                                      Final
# Access Type                                                              NaN
# Source                                                                Scopus
# EID                                                       2-s2.0-85047864637
#
#                                                                            2
# Authors                                             Jensen D.W., Machanzi T.
# Author(s) ID                                         7402549729;57202088821;
# Title                      Pull-out strength of fiberglass/epoxy composit...
# Year                                                                    2018
# Source title               33rd Technical Conference of the American Soci...
# General conference name    Technical Conference of the American Society f...
# Volume                                                                     5
# Issue                                                                    NaN
# Art. No.                                                                 NaN
# Page start                                                            3275.0
# Page end                                                              3289.0
# Page count                                                               NaN
# Cited by                                                                 NaN
# DOI                                                                      NaN
# Link                       https://www.scopus.com/inward/record.uri?eid=2...
# Affiliations               Brigham Young University, 368-E CB, Provo, UT ...
# Authors with affiliations  Jensen, D.W., Brigham Young University, 368-E ...
# Abstract                   This research demonstrated the ability to prod...
# Author Keywords                                                          NaN
# Index Keywords             Aramid fibers; Bond strength (materials); Coat...
# Document Type                                                     Conference
# Publication Stage                                                      Final
# Access Type                                                              NaN
# Source                                                                Scopus
# EID                                                       2-s2.0-85059382045

# %%
# Creating reviews per paper
authorsdf = df['Authors'].apply(lambda x: x.split(","))
authors = {author for authors in authorsdf for author in authors}
# Out:
# {' El-Essawi M.',
#  ' Snell Q.',
#  " O'Neill M.",
#  ' Allen D.',
#  'Hedengren J.D.',
#  ' Meratnia N.',
#  ' Mohamad G.',
#  ' Andersson K.',
#  ' Ames D.C.',
#  ' Sun D.',
#  ' Stambaugh A.',
#  ' Holbrook M.D.',
#  ' Camacho J.S.',
#  ' Homer E.',
#  ' Gamstedt E.K.',
#  ' Hawkins A.R.',
#  'Stankovic A.M.',
#  ' Griffitts J.',
#  ' Wendt J.O.L.',
#  ' Nixon C.A.',
#  ' Holden J.',
#  ' Ahrens J.',
#  ' Reynolds P.',
#  'Stevens K.A.',
#  'Newcomb J.E.',
#  'Oliveira P.M.',
#  ' Mehmood R.',
#  ' Amini E.',
#  ' Downing T.',
#  ' Prasad S.V.',
#  'Ogles B.',
#  ' Vajdi A.',
#  'Farnsworth C.',
#  ' Jiang Y.',
#  ' Broderick G.',
#  ' Dean D.L.',
#  ' Lang R.J.',
#  'Allred D.D.',
#  'Smith J.P.',
#  ' Schaumann L.',
#  ' Iverson B.D.',
#  ' Belanger H.',
#  ' Mehr J.',
#  ' Payette G.',
#  ' Perrinsy E.',
#  ' Senadjki A.',
#  'Farnsworth C.B.',
#  ' Harrison W.',
#  ' Black R.',
#  ' Jandron M.A.',
#  ' Schulzke C.',
#  ' Schultz S.M.',
#  ' Hughes A.',
#  ' Allen B.C.',
#  ' Leete K.M.',
#  ' Takai H.',
#  ' Ghamkhar R.',
#  'Hajimirzaie S.M.',
#  ' DeFigueiredo B.P.',
#  ' Memmott M.J.',
#  ' Witherow K.',
#  'Jain P.',
#  ' Reynolds J.',
#  ' Jensen S.',
#  ' Stewart E.',
#  ' Hueros R.A.R.',
#  ' Bybee S.M.',
#  ' Wood A.E.',
#  ' Gudbrandsen M.',
#  'Hamblin M.',
#  'Stapleton T.',
#  ' Bhat S.K.',
#  ' Han J.',
#  ' Linford M.R.',
#  ' Sommerfeldt S.D.',
#  'Tolman S.',
#  'Akagi J.',
#  'Ahn E.-Y.',
#  ' Salmon J.',
#  ' Butler M.',
#  'Pierce J.',
#  ' Schultz G.G.',
#  ' Cameron J.',
#  'Wilson P.S.',
#  'Francis B.',
#  ' Alcock C.',
#  ' Monaco P.',
#  'Bodily D.M.',
#  ' Magleby S.P.',
#  ' Abildskov T.J.',
#  ' Glorieux C.',
#  'Amini E.',
#  'Stout J.M.',
#  ' Killpack M.',
#  'Stone B.',
#  ' Eggett D.',
#  ' Lewis R.S.',
#  ' Romero M.',
#  ' Sheffield J.',
#  'George A.R.',
#  ' Mosavi H.',
#  ' Ruzindana M.',
#  'Smiley A.J.',
#  ' Viglione M.',
#  'Rossiter J.A.',
#  'Bunimovich L.',
#  ' Cathey C.',
#  ' Sowards J.B.',
#  ' Twitchell A.',
#  ' Hirschi E.',
#  'Neupane A.',
#  ' Baxter L.',
#  ' Greenburg M.J.',
#  ' Durfee D.S.',
#  ' Shishavan R.A.',
#  ' Goodrich-Hunsaker N.J.',
#  ' Calton M.F.',
#  'Knighton B.E.',
#  ' Wilding K.M.',
#  ' Jensen B.D.',
#  ' Morgan J.C.',
#  'Machanzi T.',
#  ' Layton T.',
#  ' Steven Turley R.',
#  'Jones S.H.',
#  ' Bodily P.',
#  ' Akamine M.',
#  ' King M.',
#  ' Kang C.K.',
#  ' Fonseca F.S.',
#  ' Kinnison W.',
#  ' George J.',
#  'OÕNeill M.',
#  ' Detournay E.',
#  ' Moon B.',
#  ' Howell B.F.',
#  ' Boekweg E.',
#  ' Turley R.S.',
#  ' Barber J.L.',
#  ' Spencer J.C.',
#  ' Scheibel R.S.',
#  'Salmon J.L.',
#  'Burgett J.M.',
#  'Howell L.L.',
#  ' Hedengren J.D.',
#  ' Dickinson L.',
#  ' Bohn R.E.',
#  ' Gustafson E.',
#  ' Cuesta I.',
#  'Rozsa J.',
#  ' Maynes D.',
#  ' Smith A.',
#  'Wilson A.E.',
#  ' Dahlin E.C.',
#  ' Schroedter T.L.',
#  ' Sandberg R.L.',
#  ' Argyle M.',
#  'Wanik D.',
#  ' Buie M.W.',
#  ' Jiang Z.',
#  ' Fourment L.',
#  ' Lin A.',
#  'Roundtree K.A.',
#  ' Cayeux E.',
#  'Aghito M.',
#  ' Knobles D.P.',
#  'Norman K.',
#  ' Shumway S.B.',
#  'Richards A.P.',
#  ' Wood R.L.',
#  ' Clark B.',
#  'Munro T.',
#  ' Brink K.',
#  ' Hotchkiss R.H.',
#  'Ware M.',
#  'Stanley Fujimoto M.',
#  ' Peatross J.',
#  ' Burrow D.',
#  ' Bean M.',
#  ' Bundy B.C.',
#  ' Fujimoto M.S.',
#  ' Sari_ A.T.',
#  'Shen W.',
#  ' Lee E.T.',
#  ' Wen S.-J.',
#  ' Thomas J.J.',
#  ' Daly E.',
#  'Starick T.',
#  'Bingham E.',
#  ' Patterson C.',
#  ' Garcia S.E.',
#  ' Boardman B.',
#  ' Casbeer D.',
#  'Ottosson H.J.',
#  ' Saquib M.',
#  ' Wingate D.',
#  ' Solovjov V.',
#  ' Tilahun L.E.',
#  ' Qaderi K.',
#  ' Navrotsky A.',
#  ' Hasler E.',
#  ' Killpack M.D.',
#  ' Cook A.',
#  ' Biswas A.',
#  'Moon B.G.',
#  ' Thomas M.',
#  ' Putney L.',
#  ' Thomas C.A.',
#  ' Rahmati M.',
#  'Heath D.',
#  'Hurst W.',
#  ' Nuttall J.R.',
#  'Chen G.',
#  ' Frank I.W.',
#  ' Maynes D.R.',
#  ' Cheney T.',
#  'Millard J.',
#  ' Wong R.',
#  'de Moura Oliveira P.B.',
#  ' Davidson A.D.',
#  ' III',
#  ' Olsen M.H.',
#  ' Trebino R.',
#  ' Coffman R.A.',
#  ' Lazzaroni M.',
#  ' Liu R.',
#  ' Burnett M.',
#  ' Crandall J.W.',
#  'Sargent B.',
#  'Butler J.',
#  ' Forsyth J.K.',
#  ' Howell L.',
#  ' Pham H.',
#  ' Oliphant K.',
#  'Aslani P.',
#  ' Ganjalizadeh V.',
#  'Boyce P.',
#  ' Vanfleet R.',
#  ' Kramer E.A.',
#  ' Gabriel Richardson J.',
#  ' Saftner D.A.',
#  'Hendricks L.J.',
#  ' Allred D.D.',
#  ' Pingel N.',
#  ' Bunker D.',
#  ' Passey D.J.',
#  'Bruening D.A.',
#  'Walton M.P.',
#  ' Drennon A.M.',
#  'Sansom R.L.',
#  ' Brock Kirwan C.',
#  'Hutchings B.L.',
#  ' Palma L.',
#  'Hamilton E.S.',
#  'Josephson A.J.',
#  'Prawitt D.G.',
#  ' Tolman K.A.',
#  ' Weaver J.M.',
#  ' Jensen H.',
#  ' Armknecht J.',
#  'Reynolds J.',
#  ' Bj¿rkevoll K.S.',
#  'Eixenberger J.G.',
#  ' OÕToole N.',
#  ' Petersen M.',
#  ' Prinz G.S.',
#  ' Patterson J.L.',
#  ' Fremont W.',
#  ' Gates N.S.',
#  ' Baxter J.S.',
#  ' Lawrence E.',
#  ' Sun C.',
#  ' Ochsner S.',
#  ' Aldous P.',
#  ' Elmqvist N.',
#  ' Efimov A.',
#  ' Hahn A.',
#  ' Hutchinson T.',
#  ' Howland S.M.J.',
#  'Stott M.A.',
#  ' Prince D.R.',
#  ' Gupta V.',
#  'Reese K.',
#  ' Raikes A.C.',
#  ' Ventura D.',
#  ' Lee K.',
#  'Searle H.',
#  ' Gee K.L.',
#  'Rose M.A.',
#  ' Austin D.E.',
#  ' Cole-Rhodes A.',
#  'Wall A.T.',
#  'Andrews D.W.',
#  'Jafek B.',
#  ' Hodges G.T.',
#  'La A.',
#  'Peterson M.W.',
#  ' Fullwood D.',
#  'Chang D.K.',
#  ' Palomba E.',
#  ' Thomas S.M.',
#  'Fagergren F.',
#  ' Hanson R.',
#  ' Whitehead J.',
#  ' Jackson J.',
#  'Howland S.M.J.',
#  ' Parness A.',
#  'Vaughn A.B.',
#  ' Keller A.M.',
#  ' Katayama I.',
#  'Transtrum M.K.',
#  ' Piktel E.',
#  ' Skaggs P.',
#  ' Irvin J.J.',
#  ' Ning A.',
#  ' Ray Pentecost A.',
#  ' Bodily R.',
#  ' Mishra R.K.',
#  ' Cao J.',
#  'Lyman C.A.',
#  'Maestre J.',
#  ' Guthrie S.',
#  ' Atkinson N.',
#  ' Wray K.W.',
#  ' Bybee S.',
#  ' Sun W.',
#  ' Bull D.J.',
#  ' Soderquist D.R.',
#  ' Liu Y.',
#  'Svenda V.G.',
#  ' Freeman I.',
#  ' Haghighipour N.',
#  'Zobell B.',
#  ' Cattaneo A.',
#  'Samuelson C.R.',
#  ' Eargle D.',
#  ' Nyb¿ R.',
#  'Lystrup C.',
#  ' Hatch N.W.',
#  ' Wheeler D.R.',
#  ' Bjoraker G.L.',
#  'Riding K.A.',
#  'Jackson J.S.',
#  'Wheadon J.',
#  'Miles M.P.',
#  ' Pisano D.J.',
#  ' Adams D.',
#  ' Baumgarten T.E.',
#  'Clavijo C.E.',
#  'Chen G.-M.',
#  'Tolman K.A.',
#  ' McMurray J.',
#  ' Radzinski T.',
#  ' Zimmerman T.K.',
#  'Brodie M.',
#  ' Janion M.',
#  ' Baxter A.',
#  ' Das S.K.',
#  'Wright G.A.',
#  ' Ellingson G.',
#  ' Adams B.',
#  ' Jones Z.T.',
#  'Russell D.N.',
#  ' Copley D.C.',
#  'Hollenbeck M.',
#  ' Beyzaei C.',
#  'Sorensen S.T.',
#  'Shen C.',
#  'Ynchausti C.',
#  'Lopez J.S.',
#  'Larsen B.',
#  ' York G.E.',
#  ' Smalley D.',
#  'Bush W.S.',
#  'Leung H.',
#  'Holler B.J.',
#  'Keller A.M.',
#  ' Knezevic M.',
#  ' Parks J.W.',
#  ' Le S.Q.',
#  ' Aarsnes U.J.',
#  ' Van Den Bree M.',
#  ' Hansen L.',
#  'Calvin J.J.',
#  'Wright G.',
#  ' Webber T.',
#  ' Ashida M.',
#  'Pinto T.',
#  ' Jahanshad N.',
#  ' Chou Y.',
#  ' Song R.',
#  ' Nickerl A.',
#  ' McLain T.',
#  ' Kelly J.D.',
#  ' Boster K.',
#  'Orme A.D.',
#  ' Wyatt Clegg B.',
#  ' Zacheu G.',
#  'Baskota A.',
#  ' Nelson T.W.',
#  'Hurd R.C.',
#  ' Wu J.-T.',
#  ' Foglia L.',
#  ' Rowe W.J.',
#  'Cluff S.',
#  ' Banik J.A.',
#  ' Meena G.G.',
#  ' Wisco J.',
#  ' Luna A.',
#  'Kovacevic A.',
#  ' Wilde E.A.',
#  ' Harrison W.K.',
#  'Hosler T.',
#  'Amin M.N.',
#  ' Vilela J.P.',
#  ' Protopapa S.',
#  ' Mehrnia M.R.',
#  ' Woolley A.T.',
#  ' Hirata C.M.',
#  ' Citterio M.',
#  'Wang Y.',
#  ' Cobos D.',
#  'Lee T.Y.',
#  ' Whitehead J.P.',
#  ' Zhang F.',
#  ' Hurley D.',
#  'Ozcelik D.',
#  ' Hedengren J.',
#  ' Dahlin E.',
#  ' Brewer J.',
#  'Villanueva I.',
#  ' Brown N.',
#  'Baker N.F.',
#  'Nevers D.R.',
#  ' Capotondi F.',
#  ' Han H.N.',
#  ' Chen J.Y.C.',
#  ' Brower D.',
#  ' Orfila M.',
#  ' West R.E.',
#  'Carreira M.',
#  'Morgan D.',
#  ' Morgan D.C.',
#  ' Dallon E.',
#  ' McKinley R.L.',
#  ' Ruoti S.',
#  'Hwang J.T.',
#  'Willis J.',
#  ' Murphy C.',
#  'Zou Z.',
#  'Tucker A.L.',
#  ' Wirthlin M.',
#  'Lee J.H.',
#  ' Bucki R.',
#  ' Zhao D.',
#  ' Guthrie W.S.',
#  'Khah F.S.',
#  ' Datta B.',
#  ' Zumbrun K.',
#  'Stevenson P.D.',
#  ' Monson T.',
#  ' Holtom J.',
#  ' Willett S.G.',
#  ' Cunningham A.',
#  ' Davies R.',
#  ' Hawkins L.',
#  ' Howe L.',
#  ' Cannon M.',
#  'Lang R.J.',
#  ' Lunt B.M.',
#  'Hotchkiss R.H.',
#  ' Klimas N.G.',
#  ' Risovi-Hendrickson W.',
#  ' Crane N.',
#  ' Mercer E.G.',
#  ' Lim H.',
#  ' Lin H.-H.',
#  'Thameem M.',
#  ' Avila A.',
#  ' Goode T.',
#  'Lam S.-H.',
#  ' Brice\x96o X.',
#  ' Jain P.',
#  ' Butler B.',
#  ' Moss N.D.',
#  ' Richey M.',
#  ' Shrager A.',
#  'Van Hoe B.',
#  'Gunnarsson A.',
#  ' Tamashasky B.',
#  'Pehrson N.A.',
#  'Jesiek B.K.',
#  ' Power R.',
#  'Badger J.C.',
#  'Cardall H.',
#  ' Seamons K.',
#  ' Jesiek B.',
#  ' Stephens K.K.',
#  ' Calve S.',
#  ' Harmer R.',
#  ' Bergen B.K.',
#  'Weidman J.E.',
#  ' Hutchings B.L.',
#  ' Hopkins B.',
#  'Webb D.',
#  ' Jenkins J.L.',
#  ' Flanary D.',
#  'Kunzler J.W.',
#  ' Russell B.D.',
#  'Hammon S.',
#  ' Jones K.N.',
#  ' Sahawneh L.R.',
#  ' Holt E.A.',
#  ' Craig M.',
#  'Asimaki D.',
#  ' Perrenoud A.',
#  ' Noble P.',
#  ' McCabe K.L.',
#  ' Davis R.C.',
#  ' Simon B.',
#  ' Shor R.',
#  'Nelson T.G.',
#  ' Horak P.',
#  ' Thelin C.',
#  'Kamminga J.W.',
#  ' Bentley N.L.',
#  ' Sloan C.',
#  'Ling M.',
#  ' Saric A.T.',
#  ' Emerson P.',
#  ' Mincigrucci R.',
#  ' Millard J.D.',
#  ' DeYoung J.',
#  ' Gur R.E.',
#  ' Harb J.N.',
#  'Desai A.',
#  ' Jenkins D.',
#  'Liu F.C.',
#  'Park J.',
#  ' Camplani A.',
#  ' Yan K.',
#  ' Neilsen T.B.',
#  ' Rahman L.O.A.',
#  ' Reddy V.',
#  ' Anderson M.',
#  ' Walters D.J.',
#  ' Abut F.',
#  ' Baker W.H.',
#  ' Okamoto K.',
#  ' Sellers A.D.',
#  ' Anderson B.B.',
#  ' Jacobsen A.J.',
#  ' Hsieh H.H.',
#  ' Cao Q.',
#  ' Walker W.C.',
#  ' Patel D.I.',
#  'Zhang J.',
#  'Schnepf P.D.',
#  'Chelladurai I.',
#  ' Andre F.',
#  'Christensen C.',
#  ' Asmar M.E.',
#  ' Opra J.',
#  'Desrochers C.',
#  ' Parthiban V.',
#  'Packer R.',
#  'Seymour K.',
#  ' Moss H.',
#  ' Zoltowski C.B.',
#  'Fernelius M.H.',
#  ' Smith J.P.',
#  ' Kim D.',
#  ' Larsen B.',
#  ' Miles M.P.',
#  ' Plett G.L.',
#  ' Gibson G.E.',
#  ' Johnson J.',
#  ' Belden J.',
#  ' Machanzi T.',
#  ' Field D.P.',
#  ' Talbot M.',
#  ' Pielstick B.D.',
#  ' Cook D.D.',
#  ' Brewer E.',
#  ' Buckmiller E.',
#  'Nielsen J.',
#  ' Ackerman W.',
#  ' Snow D.',
#  'Hazen G.',
#  ' Peters K.J.',
#  ' McAlpin J.T.',
#  'McClelland H.G.',
#  'Ishimwe E.',
#  ' Ragozzine D.',
#  'Jensen J.L.',
#  ' Stanley A.P.J.',
#  ' Hopkins E.',
#  ' Salvatierra G.',
#  ' Warnick S.',
#  ' Mattson C.',
#  ' Huang Y.-C.',
#  ' Laughlin K.',
#  ' Bresciano K.A.',
#  ' Vaugh A.B.',
#  ' Orme A.D.',
#  'Manning A.',
#  ' Nguyen T.',
#  ' Rawlings L.',
#  ' Harden T.',
#  ' Stagg G.G.',
#  ' Colton M.B.',
#  'Dutson J.',
#  ' Peterson C.K.',
#  ' Milana G.',
#  ' Bower A.F.',
#  ' Matsubara E.',
#  ' Marsh A.',
#  ' Hicks A.L.',
#  'Patrick B.',
#  ' Van Steenberge G.',
#  'Afran M.S.',
#  ' Geiger D.W.',
#  ' Lin C.-S.',
#  ' Wilson J.C.',
#  'Migliaccio M.',
#  ' Roberts M.',
#  ' Nygaard E.',
#  ' Taylor E.',
#  'Alvarez E.J.',
#  ' Tippmann J.D.',
#  ' Freeman C.J.',
#  ' Dye S.',
#  ' Illerhaus R.',
#  'Defigueiredo B.P.',
#  'Hayden S.',
#  ' Orme A.',
#  ' Howell L.L.',
#  'Johnson C.A.',
#  'Fanning D.T.',
#  ' Teramoto S.',
#  ' Eapen B.',
#  ' Munro T.',
#  'Francom D.',
#  'Hinton D.',
#  ' Fulda N.',
#  ' Carver V.',
#  ' Killian M.',
#  ' Lansinger V.',
#  ' Lee D.-J.',
#  ' Metro D.',
#  ' Giraud-Carrier C.',
#  ' Phipps E.R.',
#  ' Wright L.',
#  ' Wilcox E.',
#  'Adams B.R.',
#  ' Long D.G.',
#  ' Wald M.O.',
#  ' Lyman C.',
#  ' Zappala D.',
#  ' Allred D.',
#  ' Walton P.',
#  ' Shutt T.',
#  ' Zobell B.',
#  'Rendon G.T.',
#  ' Membreno K.',
#  ' Roshi D.A.',
#  ' Chiang S.-H.W.',
#  ' Tate Fanning D.',
#  'Smith R.',
#  ' Baskaran R.',
#  'Saftner D.A.',
#  ' Leto A.',
#  ' Girod H.',
#  ' Luscher D.J.',
#  ' Carsley J.E.',
#  ' Fuentes D.S.',
#  ' Bencivenga F.',
#  ' Jones M.R.',
#  ' Nelsen B.W.',
#  'Richard F.R.Y.',
#  ' Safdari M.-S.',
#  'Nordin G.P.',
#  ' Jones S.H.',
#  ' Claussen S.',
#  ' Yamashita G.',
#  'Moore K.R.',
#  'Chetty V.',
#  ' Andr\x8e F.',
#  'Jolly S.',
#  ' Carlson B.',
#  'Solovjov V.P.',
#  ' Frecker M.I.',
#  ' Prestage R.M.',
#  ' Roalf D.',
#  ' Jones T.',
#  'Reichman B.',
#  ' Lee K.-J.',
#  ' Lusk P.C.',
#  ' Petrie A.',
#  ' Nash C.',
#  ' Magleby S.',
#  ' Weidman J.E.',
#  ' Bowen L.',
#  'Ziaee M.',
#  ' Chang M.-C.F.',
#  ' Xue M.',
#  'Gates N.S.',
#  ' Willoughby D.',
#  ' Smith D.O.',
#  'Day N.',
#  ' Jensen M.A.',
#  ' Childs C.',
#  ' Bakker G.',
#  ' Emanuel B.',
#  ' Mazzeo B.A.',
#  'Bidstrup C.C.',
#  'Swindlehurst E.',
#  ' Besendorfer J.',
#  ' Turoff M.',
#  ' Basko R.',
#  'Kim J.-R.',
#  'Brown T.',
#  ' Zhang Y.',
#  ' Schmitt J.E.',
#  ' Dasgupta A.',
#  ' Owen M.',
#  ' Butail S.',
#  ' Wood D.',
#  'Tolman S.S.',
#  ' Howell B.',
#  'Stringer B.J.',
#  ' Harrisony W.K.',
#  ' Rice W.',
#  ' Quick L.C.',
#  ' Mathis T.',
#  ' Jeong Y.-H.',
#  ' Clement M.J.',
#  ' Koehler R.',
#  ' Dickinson T.',
#  ' Kochenderfer M.J.',
#  'Hanks K.N.',
#  ' Jensen D.W.',
#  ' Hirt J.R.',
#  ' Halverson D.M.',
#  ' Webb B.W.',
#  ' Fletcher M.',
#  'Yellowhorse A.D.',
#  'Lundgreen R.',
#  ' Hull T.',
#  ' Oldroyd J.',
#  ' Gorrell S.E.',
#  ' Johnson O.K.',
#  'Rich P.J.',
#  'Dearden J.',
#  ' Levin H.S.',
#  ' Averett T.',
#  ' Gladstone R.',
#  'Iverson B.D.',
#  ' Han K.-S.',
#  'Franke K.W.',
#  ' Brink K.M.',
#  ' Zhou Z.',
#  ' Farnsworth M.S.',
#  ' Pierce I.',
#  'Abut F.',
#  'Zimmerman T.',
#  'Baird G.M.',
#  ' Nmira F.',
#  ' Hatch C.',
#  'Tiwari R.',
#  ' West R.A.',
#  ' Santos-Villalobos H.',
#  ' Park J.-W.',
#  ' Velez C.',
#  ' Campbell L.E.',
#  ' Bodily P.M.',
#  'Loiseau J.',
#  ' George A.R.',
#  ' Collett T.',
#  ' MacCarty N.A.',
#  ' Francis B.L.',
#  'Allen J.T.',
#  ' Curtis C.P.',
#  ' Bauer J.M.',
#  'Weidman J.',
#  'Vaziripour E.',
#  ' Vogel S.C.',
#  ' Grames C.',
#  'Noronha D.H.',
#  'Weaver J.M.',
#  'Thompson R.',
#  ' Sandberg R.',
#  ' Angeles A.',
#  ' Black J.A.',
#  ' Black R.A.',
#  ' Linn J.',
#  ' Eicholtz M.',
#  ' Vosughi A.',
#  'Nittala S.',
#  ' Emelifeonwu J.',
#  ' Temizel-Sekeryan S.',
#  ' Exter M.',
#  ' Michael Bove V.',
#  ' Lorimer D.R.',
#  ' James M.M.',
#  'DeFigueiredo B.P.',
#  ' Willey L.',
#  ' Kress J.D.',
#  ' Fiedoruk K.',
#  ' Ngo K.',
#  'Nascimento M.R.',
#  ' Bartschi J.M.',
#  ' Trilling D.E.',
#  ' Salva K.T.',
#  ' Gallacher J.',
#  ' Kipp R.M.',
#  ' Freedman D.',
#  ' Ramos K.',
#  ' Huffaker R.',
#  ' Campbell B.D.',
#  ' Bolme D.',
#  ' Santos V.J.',
#  ' Hodge D.',
#  ' Eggett D.L.',
#  'Hunter J.G.',
#  'Stubbs C.J.',
#  ' Anderson S.',
#  ' Gandikota R.',
#  ' Butler B.W.',
#  'Fry R.',
#  ' Maccarty N.A.',
#  ' Chung W.-S.',
#  ' Sorensen C.D.',
#  ' Gatrell C.',
#  ' Seppi K.',
#  'Abraham Martin R.',
#  ' Moore J.J.',
#  'Saleh A.M.',
#  'Crampton E.B.',
#  ' Youn C.C.',
#  ' Ma F.',
#  'Rhamati M.',
#  ' Allen T.F.',
#  'Gibbons J.D.',
#  ' Nelson K.',
#  ' Rosen J.',
#  'Gallacher J.R.',
#  ' Alder C.K.',
#  ' Ware M.',
#  ' Woodfield B.F.',
#  ' Lignell D.O.',
#  'Fulda N.',
#  ' Ahn E.-Y.',
#  'Vance A.',
#  ' Pope S.A.',
#  'Farrell M.',
#  ' Rogers W.',
#  ' Jesiek B.K.',
#  ' Crockett J.',
#  ' Sulik M.',
#  ' Garcia E.',
#  'Rahman M.',
#  ' Taylor B.A.',
#  ' Hsu C.-W.',
#  ' Josephson C.',
#  'Childs B.R.',
#  ' Laughlin E.',
#  ' Hardersen P.S.',
#  ' Gallant N.D.',
#  ' Baird S.',
#  ' Shillue W.',
#  ' Bove V.M.',
#  'Horne R.R.',
#  ' Kushan L.',
#  ' Yeung E.',
#  'Ganjalizadeh V.',
#  ' Campbell E.',
#  ' Adams M.R.',
#  ' Warnick K.F.',
#  'Peterson S.',
#  'Holland T.',
#  ' Wang K.-A.',
#  ' Nielson M.',
#  ' Wall T.',
#  ' Mavrogordato M.N.',
#  ' Davis A.',
#  'Peterson C.K.',
#  'Safdari M.-S.',
#  ' Daniluk T.',
#  ' Buck D.',
#  ' Robinson K.P.',
#  ' Hutchings B.',
#  'Schultz S.',
#  ' Jonas R.K.',
#  ' Owens T.',
#  'Adams J.A.',
#  ' Thompson P.M.',
#  ' Camacho R.M.',
#  ' Gasem K.',
#  ' Stuedlein A.',
#  'Ng Y.-K.',
#  'Soltani M.',
#  ' He J.',
#  'Korimi M.',
#  ' Hong C.-F.',
#  ' K\x9fck K.',
#  ' Oevermann M.',
#  ' Adams B.R.',
#  ' Schrand A.',
#  'Guo C.',
#  ' Putney L.G.',
#  ' Heiner B.K.',
#  ' Hewson J.C.',
#  ' Hawkins A.',
#  ' Naylor T.A.',
#  ' Hill M.',
#  ' Rice M.',
#  ' Franca F.',
#  'Roy S.',
#  ' Perry S.B.',
#  'Ashcraft C.C.',
#  ' Leary H.',
#  ' Sorensen C.',
#  ' Hazen G.',
#  ' Behounek M.',
#  ' Jaramillo C.A.',
#  ' Glaab L.J.',
#  ' Edward Gibson G.',
#  'Johnson M.H.',
#  ' Hovanski Y.',
#  ' Perdue T.',
#  'Cowley A.',
#  ' Tate D.F.',
#  ' Andersen J.',
#  ' Hansen N.',
#  'Sayre A.',
#  'Taysom B.S.',
#  'Stark C.G.',
#  ' S\x87ez E.',
#  'Morales C.',
#  ' Hooper K.',
#  ' Sypherd S.',
#  ' Harper C.',
#  'Wilson M.E.',
#  ' Schmidt H.',
#  ' Beard R.',
#  'Koch D.P.',
#  ' Wright J.G.',
#  ' Smith S.P.',
#  'Soderquist D.R.',
#  ' Redd B.',
#  ' Consalvi J.-L.',
#  ' Pfau K.H.',
#  'Neilsen T.B.',
#  'Jamal A.-S.',
#  ' Goodrich M.A.',
#  ' Webb B.',
#  'Mattson C.A.',
#  'Yellowhorse A.',
#  ' Brushett F.R.',
#  'Larmore G.',
#  ' Smith D.',
#  ' Stone S.E.',
#  ' Smith J.',
#  'Black J.A.',
#  ' Song Y.',
#  ' Evans W.',
#  'Arabian F.',
#  ' Whitworth C.B.',
#  ' Hardy R.T.',
#  ' Smith T.',
#  ' Frankman D.',
#  ' Johnson C.L.',
#  ' Bender C.',
#  ' Kitching J.',
#  ' Wamick K.',
#  ' Wall T.A.',
#  ' Tang H.H.',
#  ' Swift S.H.',
#  ' Ban H.',
#  ' Custer C.H.',
#  ' Coburn J.',
#  'Cannon M.',
#  'Fujimoto M.S.',
#  ' Nir T.',
#  ' Niezgoda S.',
#  ' Moazzami F.',
#  ' Nelson T.',
#  ' Stott M.A.',
#  ' El Asmar M.',
#  ' Le K.',
#  'Jafek A.',
#  ' Youd T.L.',
#  ' Suvorov A.',
#  'Goodson M.',
#  'Thomas J.J.',
#  'Kurniawan C.',
#  ' Stankovic A.M.',
#  'Jensen D.W.',
#  ' Von Moll A.',
#  ...}
